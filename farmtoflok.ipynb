# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\anish\OneDrive\Documents\FarmToFalk_-Dev[1]\FarmToFalk -Dev\crop_recommendation.csv")

# %%
df.head()
# Out:
#     N   P   K  temperature   humidity        ph   tds    label
# 0  90  42  43    20.879744  82.002744  6.502985   902  Lettuce
# 1  85  58  41    21.770462  80.319644  7.038096  1090  Lettuce
# 2  60  55  44    23.004459  82.320763  7.840207  1101  Lettuce
# 3  74  35  40    26.491096  80.158363  6.980401   953  Lettuce
# 4  78  42  42    20.130175  81.604873  7.628473  1123  Lettuce

# %%
df['label'].nunique()
# Out:
# 22

# %%
df.tail()
# Out:
#         N   P   K  temperature   humidity        ph   tds         label
# 2195  107  34  32    26.774637  66.413269  6.780064  1066  Green onions
# 2196   99  15  27    27.417112  56.636362  6.086922  1213  Green onions
# 2197  118  33  30    24.131797  67.225123  6.362608  1225  Green onions
# 2198  117  32  34    26.272418  52.127394  6.758793   903  Green onions
# 2199  104  18  30    23.603016  60.396475  6.779833  1250  Green onions

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph          tds
# count  2200.000000  2200.000000
# mean      6.469480  1051.099091
# std       0.773938   144.962378
# min       3.504752   800.000000
# 25%       5.971693   922.000000
# 50%       6.425045  1053.000000
# 75%       6.923643  1175.000000
# max       9.935091  1300.000000

# %%
df.size
# Out:
# 17600

# %%
df.shape
# Out:
# (2200, 8)

# %%
df.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'tds', 'label'], dtype='object')

# %%
df['label'].unique()
# Out:
# array(['Lettuce', 'Spinach', 'Basil', 'Mint', 'parsley', 'Chives',
#        'Tomatoes', 'Bell peppers', 'Cucumbers', 'Strawberries',
#        'Green beans', 'Peas', 'Eggplants', 'Cannabis', 'Watercress',
#        'Radishes', 'Carrots', 'Beets', 'Celery', 'Zucchini', 'Squash',
#        'Green onions'], dtype=object)

# %%
df['label'].value_counts()
# Out:
# label
# Lettuce         100
# Spinach         100
# Squash          100
# Zucchini        100
# Celery          100
# Beets           100
# Carrots         100
# Radishes        100
# Watercress      100
# Cannabis        100
# Eggplants       100
# Peas            100
# Green beans     100
# Strawberries    100
# Cucumbers       100
# Bell peppers    100
# Tomatoes        100
# Chives          100
# parsley         100
# Mint            100
# Basil           100
# Green onions    100
# Name: count, dtype: int64

# %%
x = df[['N', 'P','K','temperature', 'humidity', 'ph', 'tds']]
y = df['label']

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(x,y,test_size = 0.2,random_state =2)

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators=20, random_state=0)
RF.fit(Xtrain,Ytrain)
# Out:
# RandomForestClassifier(n_estimators=20, random_state=0)

# %%
Y_pred = RF.predict(Xtest)

# %%
Y_pred
# Out:
# array(['Green onions', 'Strawberries', 'Strawberries', 'Zucchini',
#        'Tomatoes', 'Green onions', 'Cannabis', 'Celery', 'parsley',
#        'Peas', 'Basil', 'Squash', 'Beets', 'Chives', 'Peas', 'Spinach',
#        'Carrots', 'Bell peppers', 'Zucchini', 'Carrots', 'Green beans',
#        'Mint', 'Watercress', 'Green beans', 'Peas', 'Mint', 'Celery',
#        'Celery', 'Lettuce', 'Tomatoes', 'Strawberries', 'Basil',
#        'Tomatoes', 'Tomatoes', 'Chives', 'Green onions', 'Zucchini',
#        'Watercress', 'Bell peppers', 'Bell peppers', 'Beets',
#        'Strawberries', 'Strawberries', 'Squash', 'Chives', 'Strawberries',
#        'Strawberries', 'Tomatoes', 'Green onions', 'Basil',
#        'Green onions', 'Bell peppers', 'Zucchini', 'parsley', 'Zucchini',
#        'Cucumbers', 'Tomatoes', 'Green beans', 'Cucumbers', 'Carrots',
#        'Squash', 'Squash', 'parsley', 'Eggplants', 'parsley', 'Eggplants',
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Ytest, Y_pred)

# %%
accuracy
# Out:
# 0.9659090909090909

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Ytest, Y_pred)

# %%
from sklearn.metrics import classification_report
print(classification_report(Ytest, Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        Basil       1.00      1.00      1.00        21
#        Beets       1.00      1.00      1.00        19
# Bell peppers       0.94      0.94      0.94        16
#     Cannabis       1.00      1.00      1.00        15
#      Carrots       1.00      1.00      1.00        29
#       Celery       1.00      1.00      1.00        21
#       Chives       0.95      0.95      0.95        19
#    Cucumbers       0.95      0.91      0.93        23
#    Eggplants       1.00      1.00      1.00        18
#  Green beans       1.00      1.00      1.00        17
# Green onions       1.00      1.00      1.00        22
#      Lettuce       0.65      0.81      0.72        16
#         Mint       1.00      1.00      1.00        14
#         Peas       1.00      1.00      1.00        26
#     Radishes       1.00      1.00      1.00        13
#      Spinach       1.00      1.00      1.00        21
# ...

# %%
data = np.array([[104,18, 30, 23.603016, 60.3, 6.7, 140.91]])
prediction = RF.predict(data)
print(prediction)
# Out:
# ['Green onions']
# C:\Users\anish\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import joblib

# %%
filename = 'random_forest_model.joblib'
joblib.dump(RF, filename)
# Out:
# ['random_forest_model.joblib']

# %%
print(f"Model saved to {filename}")
# Out:
# Model saved to random_forest_model.joblib

# %%
import os
folder_path = r"C:\Users\anish\OneDrive\Desktop\farmtofolk"
full_file_path = os.path.join(folder_path, filename)
os.makedirs(folder_path, exist_ok=True)
joblib.dump(RF, full_file_path)
print(f"Model saved successfully to: {full_file_path}")
# Out:
# Model saved successfully to: C:\Users\anish\OneDrive\Desktop\farmtofolk\random_forest_model.joblib
